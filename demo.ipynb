# %%
# Out:
# ...
#   Using cached torch-2.6.0-cp310-none-macosx_11_0_arm64.whl.metadata (28 kB)
# ...
#   Using cached torchaudio-2.6.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.6 kB)
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# ...
#   Using cached antlr4_python3_runtime-4.9.3-py3-none-any.whl
# ...
#   Using cached pyyaml-6.0.3-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.4 kB)
# ...
# Using cached torch-2.6.0-cp310-none-macosx_11_0_arm64.whl (66.5 MB)
# Using cached torchaudio-2.6.0-cp310-cp310-macosx_11_0_arm64.whl (1.8 MB)
# Using cached sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached hydra_core-1.3.2-py3-none-any.whl (154 kB)
# Using cached omegaconf-2.3.0-py3-none-any.whl (79 kB)
# ...

# %%
import torch
import torchaudio

x = torch.rand(2, 18000)
x = x.mean(dim=0)
print(x.shape)
x_spec = torch.stft(x, n_fft=200, return_complex=True)
print(x_spec.shape)
# Out:
# torch.Size([18000])
# torch.Size([101, 361])
