# %%
# Out:
# ...
#   Using cached torch-2.6.0-cp310-none-macosx_11_0_arm64.whl.metadata (28 kB)
# ...
#   Using cached torchaudio-2.6.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.6 kB)
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# ...
#   Using cached antlr4_python3_runtime-4.9.3-py3-none-any.whl
# ...
#   Using cached pyyaml-6.0.3-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.4 kB)
# ...
# Using cached torch-2.6.0-cp310-none-macosx_11_0_arm64.whl (66.5 MB)
# Using cached torchaudio-2.6.0-cp310-cp310-macosx_11_0_arm64.whl (1.8 MB)
# Using cached sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached hydra_core-1.3.2-py3-none-any.whl (154 kB)
# Using cached omegaconf-2.3.0-py3-none-any.whl (79 kB)
# ...

# %%
import torch
import torchaudio

x = torch.rand(2, 18000)
x = x.mean(dim=0)
print(x.shape)
x_spec = torch.stft(x, n_fft=200, return_complex=True)
print(x_spec.shape)
# Out:
# torch.Size([18000])
# torch.Size([101, 361])

# %%
pn
# Out:
# array([61.81191561, 61.8748201 , 61.88411468, ..., 61.72932025,
#        61.77568448, 61.80187368], shape=(16000,))

# %%
from IPython.display import Audio

Audio(pn, rate=16000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 from IPython.display import Audio
# ----> 3 Audio(pn, rate=16000)
#
# NameError: name 'pn' is not defined

# %%
from src.generate_noise import generate_white_noise, generate_pink_noise, add_noise_snr
import torchaudio

clean, sr = torchaudio.load('/Users/htutb/Documents/code/Training/Python_Training/projects/lil_denoiser/test_data/sample1.wav')
clean = clean.mean(dim=0)
white_noise = generate_white_noise(len(clean))
pink_noise = generate_pink_noise(len(clean))

white_noisy_0db = add_noise_snr(clean, white_noise, 0).unsqueeze(0)
white_noisy_m10db = add_noise_snr(clean, white_noise, -10).unsqueeze(0)

pink_noisy_0db = add_noise_snr(clean, pink_noise, 0).unsqueeze(0)
pink_noisy_m10db = add_noise_snr(clean, pink_noise, -10).unsqueeze(0)
# Out:
# /opt/homebrew/lib/python3.9/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(

# %%
white_noisy_0db.shape
# Out:
# torch.Size([1, 124552])

# %%
from IPython.display import Audio
torchaudio.save('/Users/htutb/Documents/code/Training/Python_Training/projects/lil_denoiser/test_data/sample1_white_0.wav', white_noisy_0db, sample_rate=16000)
# Out:
# /opt/homebrew/lib/python3.9/site-packages/torchaudio/_backend/utils.py:337: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.save_with_torchcodec` under the hood. Some parameters like format, encoding, bits_per_sample, buffer_size, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's encoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.encoders.AudioEncoder
#   warnings.warn(

# %%
torchaudio.save('/Users/htutb/Documents/code/Training/Python_Training/projects/lil_denoiser/test_data/sample1_white_0.wav', white_noisy_0db, sample_rate=16000)
torchaudio.save('/Users/htutb/Documents/code/Training/Python_Training/projects/lil_denoiser/test_data/sample1_white_m10.wav', white_noisy_m10db, sample_rate=16000)
torchaudio.save('/Users/htutb/Documents/code/Training/Python_Training/projects/lil_denoiser/test_data/sample1_pink_0.wav', pink_noisy_0db, sample_rate=16000)
torchaudio.save('/Users/htutb/Documents/code/Training/Python_Training/projects/lil_denoiser/test_data/sample1_pink_m10.wav', pink_noisy_m10db, sample_rate=16000)
# Out:
# /opt/homebrew/lib/python3.9/site-packages/torchaudio/_backend/utils.py:337: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.save_with_torchcodec` under the hood. Some parameters like format, encoding, bits_per_sample, buffer_size, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's encoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.encoders.AudioEncoder
#   warnings.warn(
